# %% [markdown]
# <a href="https://colab.research.google.com/github/siam-000/1.-python-start/blob/main/'output_csv'.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import sys

# !wget https://raw.githubusercontent.com/siam-000/1.-python-start/refs/heads/main/Siam_Math.py

sys.path.append('/content')

import Siam_Math as mat


#print(i,end ="\n")
numofd=50
print(mat.print_pi_to_n_digits(int(numofd)))

df = pd.read_csv("/content/csvTest.csv")

for i in df:
 print("PI for digit =",i,":",mat.print_pi_to_n_digits(int(i)),end="\n")
# Out:
# --2024-11-08 14:56:54--  https://raw.githubusercontent.com/siam-000/1.-python-start/refs/heads/main/Siam_Math.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 250 [text/plain]
# Saving to: ‘Siam_Math.py.1’
#
# Siam_Math.py.1      100%[===================>]     250  --.-KB/s    in 0s
#
# 2024-11-08 14:56:54 (3.91 MB/s) - ‘Siam_Math.py.1’ saved [250/250]
#
# 3.14159265358979323846264338327950288419716939937511
# PI for digit = 12 : 3.14159265359
# PI for digit = 15 : 3.141592653589793
# PI for digit = 100 : 3.141592653589793238462643383279502884197169399375105820974944592307816406286208998628034825342117068
# ...

# %%
import pandas as pd
import sys

# !wget https://raw.githubusercontent.com/siam-000/1.-python-start/refs/heads/main/Siam_Math.py
sys.path.append('/content')
#import Siam_Math as mat
df = pd.read_csv("/content/csvTest.csv")

mylist =[]
for i in df:
  mylist.append(mat.print_pi_to_n_digits(int(i)))
  #print(mylist)

  out_df = pd.DataFrame( columns=['digit', 'pi'])
  out_df.to_csv("output.csv")

#print(mylist)


#for i in df:
 #print("PI for digit =",i,":",mat.print_pi_to_n_digits(int(i)),end="\n")
# Out:
# --2024-11-08 15:31:51--  https://raw.githubusercontent.com/siam-000/1.-python-start/refs/heads/main/Siam_Math.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 250 [text/plain]
# Saving to: ‘Siam_Math.py.3’
#
# Siam_Math.py.3      100%[===================>]     250  --.-KB/s    in 0s
#
# 2024-11-08 15:31:51 (8.88 MB/s) - ‘Siam_Math.py.3’ saved [250/250]
